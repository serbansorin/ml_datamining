# %% [markdown]
# # Modelare ML

# %% [markdown]
# Primul pas este stabilirea problemei care se doreste sa se rezolve.

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Adult

# %%
import pandas as pd

# %% [markdown]
# # Incarcam baza de date
# ## Varianta 1

# %%
 
#df=pd.read_csv('adult.data', header = None)

#df=pd.read_csv('adult.data', header = None, sep = ', ')
#df
df=pd.read_csv('adult.data', header = None, sep = ', ', engine='python')
df
# Out:
#        0                 1       2           3   4                   5   \
# 0      39         State-gov   77516   Bachelors  13       Never-married
# 1      50  Self-emp-not-inc   83311   Bachelors  13  Married-civ-spouse
# 2      38           Private  215646     HS-grad   9            Divorced
# 3      53           Private  234721        11th   7  Married-civ-spouse
# 4      28           Private  338409   Bachelors  13  Married-civ-spouse
# ...    ..               ...     ...         ...  ..                 ...
# 32556  27           Private  257302  Assoc-acdm  12  Married-civ-spouse
# 32557  40           Private  154374     HS-grad   9  Married-civ-spouse
# 32558  58           Private  151910     HS-grad   9             Widowed
# 32559  22           Private  201490     HS-grad   9       Never-married
# 32560  52      Self-emp-inc  287927     HS-grad   9  Married-civ-spouse
#
#                       6              7      8       9      10  11  12  \
# ...

# %%
names_adult_dataset = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']

# %%
df.columns=names_adult_dataset

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df['education'][0]
# Out:
# 'Bachelors'

# %%
# examinam colectia de date
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# cautam valori lipsa

df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
for col in df:
    print('coloana', col, 'are valorile:', df[col].unique(), '\n')
# Out:
# coloana age are valorile: [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#
# coloana workclass are valorile: ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
#
# coloana fnlwgt are valorile: [ 77516  83311 215646 ...  34066  84661 257302]
#
# coloana education are valorile: ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
#
# coloana education-num are valorile: [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#
# coloana marital-status are valorile: ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
#
# ...

# %% [markdown]
# ## Varianta 2

# %%
names_adult_dataset = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']

# %%
df=pd.read_csv('adult.data', names = names_adult_dataset, sep=', ', engine='python')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# # Examinam colectia de date

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %% [markdown]
# # Cautam valori lipsa

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
for col in df:
    print('coloana', col, 'are valorile:', df[col].unique())
# Out:
# coloana age are valorile: [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# coloana workclass are valorile: ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# coloana fnlwgt are valorile: [ 77516  83311 215646 ...  34066  84661 257302]
# coloana education are valorile: ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# coloana education-num are valorile: [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# coloana marital-status are valorile: ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# ...

# %%
# Mai sus am observat ca datele lipsa sunt inlocuite cu ?
# Le inlocuim cu null
df.replace('?', pd.NA, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# Cautam elemente lipsa
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %% [markdown]
# # Cleaning

# %%
# Stergem exemplele(liniile) care contin elemente nule
df=df.dropna(how='any')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education-num   30162 non-null  int64
#  5   marital-status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital-gain    30162 non-null  int64
#  11  capital-loss    30162 non-null  int64
#  12  hours-per-week  30162 non-null  int64
#  13  native-country  30162 non-null  object
#  14  income          30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education-num   30162 non-null  int64
#  5   marital-status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital-gain    30162 non-null  int64
#  11  capital-loss    30162 non-null  int64
#  12  hours-per-week  30162 non-null  int64
#  13  native-country  30162 non-null  object
#  14  income          30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Construirea modelului

# %% [markdown]
# ## Selectam din colectia data atributele care ne intereseaza in procesul de modelare (clasificare)

# %%
atribute_intrare = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country']

# %%
X = df[atribute_intrare]
X
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# Stabilim atributul tinta
y =  df.income
y
# Out:
# 0        <=50K
# 1        <=50K
# 2        <=50K
# 3        <=50K
# 4        <=50K
#          ...
# 32556    <=50K
# 32557     >50K
# 32558    <=50K
# 32559    <=50K
# 32560     >50K
# Name: income, Length: 30162, dtype: object

# %% [markdown]
# ## Importam pachetele care ne trebuie

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import OrdinalEncoder
from sklearn.tree import DecisionTreeClassifier

import matplotlib.pyplot as plt

# Import datasets, classifiers and performance metrics
from sklearn import datasets, svm, metrics

# %% [markdown]
# ## Transformarea atributelor discrete

# %%
# Selectarea atributelor discrete (de tip Object)

nume_atribute_discrete =  [nume for nume in df.columns if df[nume].dtype == 'object']
nume_atribute_discrete.remove('income')
nume_atribute_discrete
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country']

# %%
# Selectarea atributelor continui (de tip Object)
nume_atribute_continui = [nume for nume in df.columns if df[nume].dtype != 'object']
nume_atribute_continui
# Out:
# ['age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
X = df[atribute_intrare]

X_discrete = df[nume_atribute_discrete]
# X_continui = df[nume_atribute_continui]

X_copy = X.copy()


#atribute_discrete =  discrete for discrete in df.columns
enc = OrdinalEncoder()
enc.fit(X[nume_atribute_discrete])
X_copy[nume_atribute_discrete] = enc.transform(X[nume_atribute_discrete])
X = X_copy
X
df

#X.dtype
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# # naive-bayes
# https://scikit-learn.org/stable/modules/naive_bayes.html

# %% [markdown]
# ## Impartim colectia data in multime de training si multime de testare

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Alegerea modelului

# %%
# model = GaussianNB()
# model = MultinomialNB()
model = DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ## Aplicarea modelului pe multimea de training

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ## Testarea  modelului pe multimea de testare

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluarea modelului

# %%
print('Numarul de exemple clasificate incorect este', (y_test != y_pred).sum(), 'din totalul de', X_test.shape[0])
# Out:
# Numarul de exemple clasificate incorect este 1165 din totalul de 6033

# %% [markdown]
# ## Calcul metrici de evaluare a modelului:
# ### eroare, acuratete

# %%
error = (y_test != y_pred).sum()/X_test.shape[0]
error
# Out:
# 0.19310459141389028

# %%
acuratetea = 1-error
acuratetea
# Out:
# 0.8068954085861098

# %% [markdown]
# ## Matricea de confuzie

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred)
# Out:
# array([[3928,  604],
#        [ 561,  940]], dtype=int64)

# %%
disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.title("Matricea de confuzie")
plt.show()

# %% [markdown]
# ## Testarea modelului pe multimea de training

# %%
y_pred_train = model.predict(X_train)

# %%
(y_pred_train != y_train).sum()
error_train = (y_train != y_pred_train).sum()/X_train.shape[0]
error_train
# Out:
# 4.1443905673670685e-05

# %% [markdown]
# ## EXERCITIU - Testarea modelului pe multimea de testare de pe site

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test"

# %%
# df_test =  pd.read_csv(url, header = None, sep=', ', engine = 'python') # multimea este scrisa gresit (are '.' la sfarsit)

# %%
df_test =  pd.read_csv('adult.test', header = None, sep=', ', engine = 'python')

# %%
df_test.columns = names_adult_dataset

# %%
df_test.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 4   18          ?  103497  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country  income
# ...

# %%
df_test['income'] =  df_test['income'].str.rstrip('.')
df_test
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 0       25       Private  226802          11th              7
# 1       38       Private   89814       HS-grad              9
# 2       28     Local-gov  336951    Assoc-acdm             12
# 3       44       Private  160323  Some-college             10
# 4       18             ?  103497  Some-college             10
# ...    ...           ...     ...           ...            ...
# 16276   39       Private  215419     Bachelors             13
# 16277   64             ?  321403       HS-grad              9
# 16278   38       Private  374983     Bachelors             13
# 16279   44       Private   83891     Bachelors             13
# 16280   35  Self-emp-inc  182148     Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married  Machine-op-inspct       Own-child
# 1      Married-civ-spouse    Farming-fishing         Husband
# ...

# %%
df_test.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df_test.replace('?', pd.NA, inplace=True)
df_test=df_test.dropna(how='any')
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15060 entries, 0 to 16280
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             15060 non-null  int64
#  1   workclass       15060 non-null  object
#  2   fnlwgt          15060 non-null  int64
#  3   education       15060 non-null  object
#  4   education-num   15060 non-null  int64
#  5   marital-status  15060 non-null  object
#  6   occupation      15060 non-null  object
#  7   relationship    15060 non-null  object
#  8   race            15060 non-null  object
#  9   sex             15060 non-null  object
#  10  capital-gain    15060 non-null  int64
#  11  capital-loss    15060 non-null  int64
#  12  hours-per-week  15060 non-null  int64
#  13  native-country  15060 non-null  object
#  14  income          15060 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.8+ MB

# %%
df_test.head()
# Out:
#    age  workclass  fnlwgt     education  education-num      marital-status  \
# 0   25    Private  226802          11th              7       Never-married
# 1   38    Private   89814       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  160323  Some-college             10  Married-civ-spouse
# 5   34    Private  198693          10th              6       Never-married
#
#           occupation   relationship   race   sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black  Male             0             0
# 1    Farming-fishing        Husband  White  Male             0             0
# 2    Protective-serv        Husband  White  Male             0             0
# 3  Machine-op-inspct        Husband  Black  Male          7688             0
# 5      Other-service  Not-in-family  White  Male             0             0
#
#    hours-per-week native-country income
# ...

# %%
y_Test = df_test['income']
y_Test
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 5        <=50K
#          ...
# 16275    <=50K
# 16276    <=50K
# 16278    <=50K
# 16279    <=50K
# 16280     >50K
# Name: income, Length: 15060, dtype: object

# %%
X_Test = df_test.drop(columns={'income'})
X_Test.info()

enc = OrdinalEncoder()
enc.fit(X_Test)
X_Test = enc.transform(X_Test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15060 entries, 0 to 16280
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             15060 non-null  int64
#  1   workclass       15060 non-null  object
#  2   fnlwgt          15060 non-null  int64
#  3   education       15060 non-null  object
#  4   education-num   15060 non-null  int64
#  5   marital-status  15060 non-null  object
#  6   occupation      15060 non-null  object
#  7   relationship    15060 non-null  object
#  8   race            15060 non-null  object
#  9   sex             15060 non-null  object
#  10  capital-gain    15060 non-null  int64
#  11  capital-loss    15060 non-null  int64
#  12  hours-per-week  15060 non-null  int64
#  13  native-country  15060 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 1.7+ MB

# %%
y_Pred = model.predict(X_Test)
print('Numarul de exemple clasificate incorect este', (y_Test != y_Pred).sum(), 'din totalul de', X_Test.shape[0])
error = (y_Test != y_Pred).sum()/X_Test.shape[0]
error
# Out:
# Numarul de exemple clasificate incorect este 4689 din totalul de 15060
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 0.31135458167330676

# %%
# Out:
# array([[8.0000e+00, 2.0000e+00, 8.3150e+03, ..., 0.0000e+00, 3.9000e+01,
#         3.7000e+01],
#        [2.1000e+01, 2.0000e+00, 1.7540e+03, ..., 0.0000e+00, 4.9000e+01,
#         3.7000e+01],
#        [1.1000e+01, 1.0000e+00, 1.0750e+04, ..., 0.0000e+00, 3.9000e+01,
#         3.7000e+01],
#        ...,
#        [2.1000e+01, 2.0000e+00, 1.1193e+04, ..., 0.0000e+00, 4.9000e+01,
#         3.7000e+01],
#        [2.7000e+01, 2.0000e+00, 1.5930e+03, ..., 0.0000e+00, 3.9000e+01,
#         3.7000e+01],
#        [1.8000e+01, 3.0000e+00, 6.0620e+03, ..., 0.0000e+00, 5.9000e+01,
#         3.7000e+01]])
